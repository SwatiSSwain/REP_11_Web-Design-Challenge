# %%
# Dependencies and Setup
import pandas as pd
import os

# %%
#load csv into dataframe
load_csv = "cities.csv"
cities_df = pd.read_csv(load_csv)
cities_df.head()
# Out:
#    City_ID           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        ushuaia -54.80  -68.30     50.00        69          75
# 1        1       victoria  22.29  114.16     75.00        88          33
# 2        2           chuy -33.70  -53.46     66.63        82          18
# 3        3   rio gallegos -51.62  -69.22     60.80        51          75
# 4        4  mar del plata -38.00  -57.56     75.20        50           1
#
#    Wind Speed Country        Date
# 0       18.34      AR  1587239810
# 1        8.01      HK  1587240323
# 2        7.23      UY  1587240487
# 3       20.80      AR  1587240086
# 4       16.11      AR  1587240201

# %%
#Generate html script from the df
html_table = cities_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>ushuaia</td>\n      <td>-54.80</td>\n      <td>-68.30</td>\n      <td>50.00</td>\n      <td>69</td>\n      <td>75</td>\n      <td>18.34</td>\n      <td>AR</td>\n      <td>1587239810</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>victoria</td>\n      <td>22.29</td>\n      <td>114.16</td>\n      <td>75.00</td>\n      <td>88</td>\n      <td>33</td>\n      <td>8.01</td>\n      <td>HK</td>\n      <td>1587240323</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>chuy</td>\n      <td>-33.70</td>\n      <td>-53.46</td>\n    
# ...

# %%
#Strip unwanted newlines
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City_ID</th>      <th>City</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Humidity</th>      <th>Cloudiness</th>      <th>Wind Speed</th>      <th>Country</th>      <th>Date</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>0</td>      <td>ushuaia</td>      <td>-54.80</td>      <td>-68.30</td>      <td>50.00</td>      <td>69</td>      <td>75</td>      <td>18.34</td>      <td>AR</td>      <td>1587239810</td>    </tr>    <tr>      <th>1</th>      <td>1</td>      <td>victoria</td>      <td>22.29</td>      <td>114.16</td>      <td>75.00</td>      <td>88</td>      <td>33</td>      <td>8.01</td>      <td>HK</td>      <td>1587240323</td>    </tr>    <tr>      <th>2</th>      <td>2</td>      <td>chuy</td>      <td>-33.70</td>      <td>-53.46</td>      <td>66.63</td>      <td>82</td>      <td>18</td>      <td>7.23</td>      <td>UY</td>      <td>15
# ...

# %%
#Save the HTML file
cities_df.to_html('..\pandas_table.html', index=False)
